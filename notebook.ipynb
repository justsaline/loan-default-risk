# %%
import pandas as pd
# Out:
# Running cells with 'venv (3.14.6.final.0) (Python 3.14.6)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/justarmaan/Documents/repos/loan-default-risk/venv/bin/python -m pip install ipykernel -U --force-reinstall'
